# %%
import pandas as pd
import os

# Load the curated dataset
df = pd.read_csv("../data/cleaned/grocery_stores_v1_curated.csv")

# Filter for confirmed real stores that are not real grocery stores
real = df[
    (df['IS_REAL_GROCERY'] == True) &
    (df['IS_JUNK_STORE'] == False)
].copy()

# Fill missing Community values
real['Community'] = real['Community'].fillna('Unknown')

# Summary of top real-heavy communities
real_by_community = real['Community'].value_counts().reset_index()
real_by_community.columns = ['Community', 'RealCount']
print("📊 Top real store communities:")
print(real_by_community.head(10))

# Create output directory
output_dir = "../data/real_review/"
os.makedirs(output_dir, exist_ok=True)

# Export CSVs per community
for community in real['Community'].unique():
    community_str = str(community).lower().replace(' ', '_')
    file_path = os.path.join(output_dir, f"real_{community_str}.csv")
    community_df = real[real['Community'] == community]
    community_df.to_csv(file_path, index=False)
    print(f"✅ Saved {len(community_df)} records for '{community}' to {file_path}")
# Out:
# 📊 Top real store communities:
#          Community  RealCount
# 0       WEST RIDGE         49
# 1   SOUTH LAWNDALE         44
# 2   BELMONT CRAGIN         41
# 3  NEAR NORTH SIDE         38
# 4     CHICAGO LAWN         38
# 5    HUMBOLDT PARK         35
# 6      SOUTH SHORE         35
# 7          CHATHAM         35
# 8        WEST TOWN         32
# 9      ALBANY PARK         32
# ✅ Saved 29 records for 'NEAR WEST SIDE' to ../data/real_review/real_near_west_side.csv
# ✅ Saved 18 records for 'AUSTIN' to ../data/real_review/real_austin.csv
# ✅ Saved 35 records for 'CHATHAM' to ../data/real_review/real_chatham.csv
# ✅ Saved 13 records for 'MORGAN PARK' to ../data/real_review/real_morgan_park.csv
# ✅ Saved 5 records for 'CALUMET HEIGHTS' to ../data/real_review/real_calumet_heights.csv
# ✅ Saved 10 records for 'GARFIELD RIDGE' to ../data/real_review/real_garfield_ridge.csv
# ✅ Saved 28 records for 'NEW CITY' to ../data/real_review/real_new_city.csv
# ✅ Saved 21 records for 'AVONDALE' to ../data/real_review/real_avondale.csv
# ✅ Saved 32 records for 'WEST TOWN' to ../data/real_review/real_west_town.csv
# ✅ Saved 41 records for 'BELMONT CRAGIN' to ../data/real_review/real_belmont_cragin.csv
# ✅ Saved 38 records for 'CHICAGO LAWN' to ../data/real_review/real_chicago_lawn.csv
# ✅ Saved 10 records for 'HYDE PARK' to ../data/real_review/real_hyde_park.csv
# ✅ Saved 32 records for 'ALBANY PARK' to ../data/real_review/real_albany_park.csv
# ✅ Saved 9 records for 'WEST LAWN' to ../data/real_review/real_west_lawn.csv
# ✅ Saved 16 records for 'EAST GARFIELD PARK' to ../data/real_review/real_east_garfield_park.csv
# ✅ Saved 8 records for 'SOUTH DEERING' to ../data/real_review/real_south_deering.csv
# ✅ Saved 44 records for 'SOUTH LAWNDALE' to ../data/real_review/real_south_lawndale.csv
# ✅ Saved 6 records for 'JEFFERSON PARK' to ../data/real_review/real_jefferson_park.csv
# ✅ Saved 29 records for 'AUBURN GRESHAM' to ../data/real_review/real_auburn_gresham.csv
# ✅ Saved 11 records for 'NORTH CENTER' to ../data/real_review/real_north_center.csv
# ✅ Saved 25 records for 'PORTAGE PARK' to ../data/real_review/real_portage_park.csv
# ✅ Saved 30 records for 'UPTOWN' to ../data/real_review/real_uptown.csv
# ✅ Saved 5 records for 'ARCHER HEIGHTS' to ../data/real_review/real_archer_heights.csv
# ✅ Saved 24 records for 'IRVING PARK' to ../data/real_review/real_irving_park.csv
# ✅ Saved 1 records for 'MOUNT GREENWOOD' to ../data/real_review/real_mount_greenwood.csv
# ✅ Saved 24 records for 'WEST ENGLEWOOD' to ../data/real_review/real_west_englewood.csv
# ✅ Saved 38 records for 'NEAR NORTH SIDE' to ../data/real_review/real_near_north_side.csv
# ✅ Saved 35 records for 'SOUTH SHORE' to ../data/real_review/real_south_shore.csv
# ✅ Saved 30 records for 'LOOP' to ../data/real_review/real_loop.csv
# ✅ Saved 6 records for 'MCKINLEY PARK' to ../data/real_review/real_mckinley_park.csv
# ✅ Saved 14 records for 'WASHINGTON HEIGHTS' to ../data/real_review/real_washington_heights.csv
# ✅ Saved 25 records for 'NORTH LAWNDALE' to ../data/real_review/real_north_lawndale.csv
# ✅ Saved 35 records for 'HUMBOLDT PARK' to ../data/real_review/real_humboldt_park.csv
# ✅ Saved 26 records for 'EDGEWATER' to ../data/real_review/real_edgewater.csv
# ✅ Saved 9 records for 'DOUGLAS' to ../data/real_review/real_douglas.csv
# ✅ Saved 29 records for 'LAKE VIEW' to ../data/real_review/real_lake_view.csv
# ✅ Saved 6 records for 'EAST SIDE' to ../data/real_review/real_east_side.csv
# ✅ Saved 13 records for 'WOODLAWN' to ../data/real_review/real_woodlawn.csv
# ✅ Saved 14 records for 'DUNNING' to ../data/real_review/real_dunning.csv
# ✅ Saved 21 records for 'ROSELAND' to ../data/real_review/real_roseland.csv
# ✅ Saved 19 records for 'LINCOLN PARK' to ../data/real_review/real_lincoln_park.csv
# ✅ Saved 8 records for 'HERMOSA' to ../data/real_review/real_hermosa.csv
# ✅ Saved 13 records for 'GAGE PARK' to ../data/real_review/real_gage_park.csv
# ✅ Saved 19 records for 'SOUTH CHICAGO' to ../data/real_review/real_south_chicago.csv
# ✅ Saved 21 records for 'LOWER WEST SIDE' to ../data/real_review/real_lower_west_side.csv
# ✅ Saved 28 records for 'ROGERS PARK' to ../data/real_review/real_rogers_park.csv
# ✅ Saved 6 records for 'NORWOOD PARK' to ../data/real_review/real_norwood_park.csv
# ✅ Saved 49 records for 'WEST RIDGE' to ../data/real_review/real_west_ridge.csv
# ✅ Saved 3 records for 'FOREST GLEN' to ../data/real_review/real_forest_glen.csv
# ✅ Saved 3 records for 'CLEARING' to ../data/real_review/real_clearing.csv
# ✅ Saved 18 records for 'ARMOUR SQUARE' to ../data/real_review/real_armour_square.csv
# ✅ Saved 3 records for 'NORTH PARK' to ../data/real_review/real_north_park.csv
# ✅ Saved 10 records for 'ASHBURN' to ../data/real_review/real_ashburn.csv
# ✅ Saved 18 records for 'ENGLEWOOD' to ../data/real_review/real_englewood.csv
# ✅ Saved 14 records for 'LINCOLN SQUARE' to ../data/real_review/real_lincoln_square.csv
# ✅ Saved 3 records for 'OHARE' to ../data/real_review/real_ohare.csv
# ✅ Saved 7 records for 'WEST ELSDON' to ../data/real_review/real_west_elsdon.csv
# ✅ Saved 22 records for 'LOGAN SQUARE' to ../data/real_review/real_logan_square.csv
# ✅ Saved 15 records for 'WEST GARFIELD PARK' to ../data/real_review/real_west_garfield_park.csv
# ✅ Saved 11 records for 'NEAR SOUTH SIDE' to ../data/real_review/real_near_south_side.csv
# ✅ Saved 17 records for 'WEST PULLMAN' to ../data/real_review/real_west_pullman.csv
# ✅ Saved 30 records for 'GREATER GRAND CROSSING' to ../data/real_review/real_greater_grand_crossing.csv
# ✅ Saved 4 records for 'BEVERLY' to ../data/real_review/real_beverly.csv
# ✅ Saved 5 records for 'HEGEWISCH' to ../data/real_review/real_hegewisch.csv
# ✅ Saved 4 records for 'PULLMAN' to ../data/real_review/real_pullman.csv
# ✅ Saved 4 records for 'BRIDGEPORT' to ../data/real_review/real_bridgeport.csv
# ✅ Saved 11 records for 'GRAND BOULEVARD' to ../data/real_review/real_grand_boulevard.csv
# ✅ Saved 14 records for 'BRIGHTON PARK' to ../data/real_review/real_brighton_park.csv
# ✅ Saved 6 records for 'WASHINGTON PARK' to ../data/real_review/real_washington_park.csv
# ✅ Saved 1 records for 'EDISON PARK' to ../data/real_review/real_edison_park.csv
# ✅ Saved 2 records for 'MONTCLARE' to ../data/real_review/real_montclare.csv
# ✅ Saved 7 records for 'AVALON PARK' to ../data/real_review/real_avalon_park.csv
# ✅ Saved 4 records for 'KENWOOD' to ../data/real_review/real_kenwood.csv
# ✅ Saved 1 records for 'RIVERDALE' to ../data/real_review/real_riverdale.csv
# ✅ Saved 2 records for 'FULLER PARK' to ../data/real_review/real_fuller_park.csv
