# %%
import pandas as pd
import os

# Load the curated dataset
df = pd.read_csv("../data/cleaned/grocery_stores_v1_curated.csv")

# Filter for unclassified stores and make an explicit copy
unclassified = df[
    (df['IS_REAL_GROCERY'] == False) &
    (df['IS_JUNK_STORE'] == False)
].copy()  # 👈 This removes the warning

# Fill missing Community values with a placeholder
unclassified['Community'] = unclassified['Community'].fillna('Unknown')

# Group by community area
unclassified_by_community = unclassified['Community'].value_counts().reset_index()
unclassified_by_community.columns = ['Community', 'UnclassifiedCount']
print(unclassified_by_community.head(10))

# Create output directory
output_dir = "../data/unclassified_review/"
os.makedirs(output_dir, exist_ok=True)

# Export CSVs per community
for community in unclassified['Community'].unique():
    community_str = str(community).lower().replace(' ', '_')
    file_path = os.path.join(output_dir, f"unclassified_{community_str}.csv")
    community_df = unclassified[unclassified['Community'] == community]
    community_df.to_csv(file_path, index=False)
    print(f"✅ Saved {len(community_df)} records for '{community}' to {file_path}")
# Out:
#          Community  UnclassifiedCount
# 0           AUSTIN                116
# 1       WEST RIDGE                 59
# 2  NEAR NORTH SIDE                 58
# 3      ALBANY PARK                 55
# 4        WEST TOWN                 54
# 5   SOUTH LAWNDALE                 53
# 6    HUMBOLDT PARK                 50
# 7             LOOP                 48
# 8   BELMONT CRAGIN                 42
# 9   NEAR WEST SIDE                 41
# ✅ Saved 40 records for 'GREATER GRAND CROSSING' to ../data/review/unclassified_greater_grand_crossing.csv
# ✅ Saved 11 records for 'WASHINGTON HEIGHTS' to ../data/review/unclassified_washington_heights.csv
# ✅ Saved 29 records for 'UPTOWN' to ../data/review/unclassified_uptown.csv
# ✅ Saved 13 records for 'WOODLAWN' to ../data/review/unclassified_woodlawn.csv
# ✅ Saved 16 records for 'WEST LAWN' to ../data/review/unclassified_west_lawn.csv
# ✅ Saved 36 records for 'LOWER WEST SIDE' to ../data/review/unclassified_lower_west_side.csv
# ✅ Saved 55 records for 'ALBANY PARK' to ../data/review/unclassified_albany_park.csv
# ✅ Saved 50 records for 'HUMBOLDT PARK' to ../data/review/unclassified_humboldt_park.csv
# ✅ Saved 40 records for 'LAKE VIEW' to ../data/review/unclassified_lake_view.csv
# ✅ Saved 42 records for 'BELMONT CRAGIN' to ../data/review/unclassified_belmont_cragin.csv
# ✅ Saved 116 records for 'AUSTIN' to ../data/review/unclassified_austin.csv
# ✅ Saved 4 records for 'EAST SIDE' to ../data/review/unclassified_east_side.csv
# ✅ Saved 14 records for 'DUNNING' to ../data/review/unclassified_dunning.csv
# ✅ Saved 17 records for 'AVONDALE' to ../data/review/unclassified_avondale.csv
# ✅ Saved 40 records for 'LOGAN SQUARE' to ../data/review/unclassified_logan_square.csv
# ✅ Saved 25 records for 'CHATHAM' to ../data/review/unclassified_chatham.csv
# ✅ Saved 24 records for 'LINCOLN PARK' to ../data/review/unclassified_lincoln_park.csv
# ✅ Saved 38 records for 'ROGERS PARK' to ../data/review/unclassified_rogers_park.csv
# ✅ Saved 6 records for 'JEFFERSON PARK' to ../data/review/unclassified_jefferson_park.csv
# ✅ Saved 32 records for 'SOUTH SHORE' to ../data/review/unclassified_south_shore.csv
# ✅ Saved 26 records for 'AUBURN GRESHAM' to ../data/review/unclassified_auburn_gresham.csv
# ✅ Saved 58 records for 'NEAR NORTH SIDE' to ../data/review/unclassified_near_north_side.csv
# ✅ Saved 30 records for 'WEST GARFIELD PARK' to ../data/review/unclassified_west_garfield_park.csv
# ✅ Saved 48 records for 'LOOP' to ../data/review/unclassified_loop.csv
# ✅ Saved 36 records for 'NEW CITY' to ../data/review/unclassified_new_city.csv
# ✅ Saved 19 records for 'ENGLEWOOD' to ../data/review/unclassified_englewood.csv
# ✅ Saved 59 records for 'WEST RIDGE' to ../data/review/unclassified_west_ridge.csv
# ✅ Saved 7 records for 'MONTCLARE' to ../data/review/unclassified_montclare.csv
# ✅ Saved 39 records for 'CHICAGO LAWN' to ../data/review/unclassified_chicago_lawn.csv
# ✅ Saved 5 records for 'EDISON PARK' to ../data/review/unclassified_edison_park.csv
# ✅ Saved 26 records for 'WEST ENGLEWOOD' to ../data/review/unclassified_west_englewood.csv
# ✅ Saved 28 records for 'NORTH LAWNDALE' to ../data/review/unclassified_north_lawndale.csv
# ✅ Saved 8 records for 'GRAND BOULEVARD' to ../data/review/unclassified_grand_boulevard.csv
# ✅ Saved 5 records for 'MOUNT GREENWOOD' to ../data/review/unclassified_mount_greenwood.csv
# ✅ Saved 10 records for 'SOUTH DEERING' to ../data/review/unclassified_south_deering.csv
# ✅ Saved 54 records for 'WEST TOWN' to ../data/review/unclassified_west_town.csv
# ✅ Saved 26 records for 'IRVING PARK' to ../data/review/unclassified_irving_park.csv
# ✅ Saved 11 records for 'ASHBURN' to ../data/review/unclassified_ashburn.csv
# ✅ Saved 41 records for 'NEAR WEST SIDE' to ../data/review/unclassified_near_west_side.csv
# ✅ Saved 5 records for 'DOUGLAS' to ../data/review/unclassified_douglas.csv
# ✅ Saved 53 records for 'SOUTH LAWNDALE' to ../data/review/unclassified_south_lawndale.csv
# ✅ Saved 14 records for 'SOUTH CHICAGO' to ../data/review/unclassified_south_chicago.csv
# ✅ Saved 20 records for 'GAGE PARK' to ../data/review/unclassified_gage_park.csv
# ✅ Saved 6 records for 'CLEARING' to ../data/review/unclassified_clearing.csv
# ✅ Saved 5 records for 'EAST GARFIELD PARK' to ../data/review/unclassified_east_garfield_park.csv
# ✅ Saved 2 records for 'RIVERDALE' to ../data/review/unclassified_riverdale.csv
# ✅ Saved 7 records for 'NEAR SOUTH SIDE' to ../data/review/unclassified_near_south_side.csv
# ✅ Saved 7 records for 'MORGAN PARK' to ../data/review/unclassified_morgan_park.csv
# ✅ Saved 8 records for 'HYDE PARK' to ../data/review/unclassified_hyde_park.csv
# ✅ Saved 4 records for 'KENWOOD' to ../data/review/unclassified_kenwood.csv
# ✅ Saved 8 records for 'WASHINGTON PARK' to ../data/review/unclassified_washington_park.csv
# ✅ Saved 10 records for 'ARCHER HEIGHTS' to ../data/review/unclassified_archer_heights.csv
# ✅ Saved 32 records for 'BRIGHTON PARK' to ../data/review/unclassified_brighton_park.csv
# ✅ Saved 32 records for 'PORTAGE PARK' to ../data/review/unclassified_portage_park.csv
# ✅ Saved 12 records for 'WEST PULLMAN' to ../data/review/unclassified_west_pullman.csv
# ✅ Saved 20 records for 'ARMOUR SQUARE' to ../data/review/unclassified_armour_square.csv
# ✅ Saved 2 records for 'Unknown' to ../data/review/unclassified_unknown.csv
# ✅ Saved 6 records for 'MCKINLEY PARK' to ../data/review/unclassified_mckinley_park.csv
# ✅ Saved 18 records for 'EDGEWATER' to ../data/review/unclassified_edgewater.csv
# ✅ Saved 8 records for 'GARFIELD RIDGE' to ../data/review/unclassified_garfield_ridge.csv
# ✅ Saved 18 records for 'LINCOLN SQUARE' to ../data/review/unclassified_lincoln_square.csv
# ✅ Saved 12 records for 'NORTH PARK' to ../data/review/unclassified_north_park.csv
# ✅ Saved 7 records for 'OHARE' to ../data/review/unclassified_ohare.csv
# ✅ Saved 12 records for 'HERMOSA' to ../data/review/unclassified_hermosa.csv
# ✅ Saved 7 records for 'FOREST GLEN' to ../data/review/unclassified_forest_glen.csv
# ✅ Saved 24 records for 'ROSELAND' to ../data/review/unclassified_roseland.csv
# ✅ Saved 15 records for 'NORTH CENTER' to ../data/review/unclassified_north_center.csv
# ✅ Saved 3 records for 'AVALON PARK' to ../data/review/unclassified_avalon_park.csv
# ✅ Saved 12 records for 'BRIDGEPORT' to ../data/review/unclassified_bridgeport.csv
# ✅ Saved 3 records for 'WEST ELSDON' to ../data/review/unclassified_west_elsdon.csv
# ✅ Saved 2 records for 'CALUMET HEIGHTS' to ../data/review/unclassified_calumet_heights.csv
# ✅ Saved 1 records for 'FULLER PARK' to ../data/review/unclassified_fuller_park.csv
# ✅ Saved 2 records for 'BEVERLY' to ../data/review/unclassified_beverly.csv
# ✅ Saved 1 records for 'HEGEWISCH' to ../data/review/unclassified_hegewisch.csv
# ✅ Saved 2 records for 'PULLMAN' to ../data/review/unclassified_pullman.csv
# ✅ Saved 2 records for 'NORWOOD PARK' to ../data/review/unclassified_norwood_park.csv
