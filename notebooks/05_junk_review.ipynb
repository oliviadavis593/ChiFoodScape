# %%
import pandas as pd
import os

# Load the curated dataset
df = pd.read_csv("../data/cleaned/grocery_stores_v1_curated.csv")

# Filter for confirmed junk stores that are not real grocery stores
junk = df[
    (df['IS_REAL_GROCERY'] == False) &
    (df['IS_JUNK_STORE'] == True)
].copy()

# Fill missing Community values
junk['Community'] = junk['Community'].fillna('Unknown')

# Summary of top junk-heavy communities
junk_by_community = junk['Community'].value_counts().reset_index()
junk_by_community.columns = ['Community', 'JunkCount']
print("📊 Top junk store communities:")
print(junk_by_community.head(10))

# Create output directory
output_dir = "../data/junk_review/"
os.makedirs(output_dir, exist_ok=True)

# Export CSVs per community
for community in junk['Community'].unique():
    community_str = str(community).lower().replace(' ', '_')
    file_path = os.path.join(output_dir, f"junk_{community_str}.csv")
    community_df = junk[junk['Community'] == community]
    community_df.to_csv(file_path, index=False)
    print(f"✅ Saved {len(community_df)} records for '{community}' to {file_path}")
# Out:
# 📊 Top junk store communities:
#          Community  JunkCount
# 0           AUSTIN        100
# 1             LOOP         85
# 2     LOGAN SQUARE         52
# 3  NEAR NORTH SIDE         49
# 4        LAKE VIEW         48
# 5   SOUTH LAWNDALE         46
# 6        ENGLEWOOD         45
# 7   AUBURN GRESHAM         44
# 8        WEST TOWN         41
# 9   BELMONT CRAGIN         39
# ✅ Saved 35 records for 'NORTH LAWNDALE' to ../data/junk_review/junk_north_lawndale.csv
# ✅ Saved 29 records for 'NEW CITY' to ../data/junk_review/junk_new_city.csv
# ✅ Saved 37 records for 'CHATHAM' to ../data/junk_review/junk_chatham.csv
# ✅ Saved 39 records for 'CHICAGO LAWN' to ../data/junk_review/junk_chicago_lawn.csv
# ✅ Saved 8 records for 'WASHINGTON PARK' to ../data/junk_review/junk_washington_park.csv
# ✅ Saved 16 records for 'WOODLAWN' to ../data/junk_review/junk_woodlawn.csv
# ✅ Saved 32 records for 'ROGERS PARK' to ../data/junk_review/junk_rogers_park.csv
# ✅ Saved 100 records for 'AUSTIN' to ../data/junk_review/junk_austin.csv
# ✅ Saved 10 records for 'NORTH PARK' to ../data/junk_review/junk_north_park.csv
# ✅ Saved 37 records for 'GREATER GRAND CROSSING' to ../data/junk_review/junk_greater_grand_crossing.csv
# ✅ Saved 17 records for 'WASHINGTON HEIGHTS' to ../data/junk_review/junk_washington_heights.csv
# ✅ Saved 39 records for 'BELMONT CRAGIN' to ../data/junk_review/junk_belmont_cragin.csv
# ✅ Saved 36 records for 'HUMBOLDT PARK' to ../data/junk_review/junk_humboldt_park.csv
# ✅ Saved 52 records for 'LOGAN SQUARE' to ../data/junk_review/junk_logan_square.csv
# ✅ Saved 38 records for 'NEAR WEST SIDE' to ../data/junk_review/junk_near_west_side.csv
# ✅ Saved 45 records for 'ENGLEWOOD' to ../data/junk_review/junk_englewood.csv
# ✅ Saved 38 records for 'WEST RIDGE' to ../data/junk_review/junk_west_ridge.csv
# ✅ Saved 8 records for 'MCKINLEY PARK' to ../data/junk_review/junk_mckinley_park.csv
# ✅ Saved 22 records for 'AVONDALE' to ../data/junk_review/junk_avondale.csv
# ✅ Saved 85 records for 'LOOP' to ../data/junk_review/junk_loop.csv
# ✅ Saved 49 records for 'NEAR NORTH SIDE' to ../data/junk_review/junk_near_north_side.csv
# ✅ Saved 24 records for 'EAST GARFIELD PARK' to ../data/junk_review/junk_east_garfield_park.csv
# ✅ Saved 33 records for 'WEST ENGLEWOOD' to ../data/junk_review/junk_west_englewood.csv
# ✅ Saved 10 records for 'DUNNING' to ../data/junk_review/junk_dunning.csv
# ✅ Saved 27 records for 'UPTOWN' to ../data/junk_review/junk_uptown.csv
# ✅ Saved 15 records for 'LOWER WEST SIDE' to ../data/junk_review/junk_lower_west_side.csv
# ✅ Saved 23 records for 'LINCOLN PARK' to ../data/junk_review/junk_lincoln_park.csv
# ✅ Saved 10 records for 'MOUNT GREENWOOD' to ../data/junk_review/junk_mount_greenwood.csv
# ✅ Saved 33 records for 'SOUTH SHORE' to ../data/junk_review/junk_south_shore.csv
# ✅ Saved 16 records for 'NORTH CENTER' to ../data/junk_review/junk_north_center.csv
# ✅ Saved 44 records for 'AUBURN GRESHAM' to ../data/junk_review/junk_auburn_gresham.csv
# ✅ Saved 7 records for 'MONTCLARE' to ../data/junk_review/junk_montclare.csv
# ✅ Saved 24 records for 'SOUTH CHICAGO' to ../data/junk_review/junk_south_chicago.csv
# ✅ Saved 41 records for 'WEST TOWN' to ../data/junk_review/junk_west_town.csv
# ✅ Saved 11 records for 'JEFFERSON PARK' to ../data/junk_review/junk_jefferson_park.csv
# ✅ Saved 5 records for 'KENWOOD' to ../data/junk_review/junk_kenwood.csv
# ✅ Saved 12 records for 'WEST ELSDON' to ../data/junk_review/junk_west_elsdon.csv
# ✅ Saved 46 records for 'SOUTH LAWNDALE' to ../data/junk_review/junk_south_lawndale.csv
# ✅ Saved 22 records for 'LINCOLN SQUARE' to ../data/junk_review/junk_lincoln_square.csv
# ✅ Saved 6 records for 'CALUMET HEIGHTS' to ../data/junk_review/junk_calumet_heights.csv
# ✅ Saved 34 records for 'IRVING PARK' to ../data/junk_review/junk_irving_park.csv
# ✅ Saved 25 records for 'WEST GARFIELD PARK' to ../data/junk_review/junk_west_garfield_park.csv
# ✅ Saved 19 records for 'WEST LAWN' to ../data/junk_review/junk_west_lawn.csv
# ✅ Saved 6 records for 'ARMOUR SQUARE' to ../data/junk_review/junk_armour_square.csv
# ✅ Saved 4 records for 'PULLMAN' to ../data/junk_review/junk_pullman.csv
# ✅ Saved 48 records for 'LAKE VIEW' to ../data/junk_review/junk_lake_view.csv
# ✅ Saved 15 records for 'HERMOSA' to ../data/junk_review/junk_hermosa.csv
# ✅ Saved 36 records for 'PORTAGE PARK' to ../data/junk_review/junk_portage_park.csv
# ✅ Saved 3 records for 'OHARE' to ../data/junk_review/junk_ohare.csv
# ✅ Saved 32 records for 'ROSELAND' to ../data/junk_review/junk_roseland.csv
# ✅ Saved 8 records for 'AVALON PARK' to ../data/junk_review/junk_avalon_park.csv
# ✅ Saved 26 records for 'ASHBURN' to ../data/junk_review/junk_ashburn.csv
# ✅ Saved 16 records for 'GAGE PARK' to ../data/junk_review/junk_gage_park.csv
# ✅ Saved 14 records for 'GRAND BOULEVARD' to ../data/junk_review/junk_grand_boulevard.csv
# ✅ Saved 23 records for 'ALBANY PARK' to ../data/junk_review/junk_albany_park.csv
# ✅ Saved 21 records for 'WEST PULLMAN' to ../data/junk_review/junk_west_pullman.csv
# ✅ Saved 19 records for 'GARFIELD RIDGE' to ../data/junk_review/junk_garfield_ridge.csv
# ✅ Saved 12 records for 'MORGAN PARK' to ../data/junk_review/junk_morgan_park.csv
# ✅ Saved 5 records for 'EAST SIDE' to ../data/junk_review/junk_east_side.csv
# ✅ Saved 27 records for 'EDGEWATER' to ../data/junk_review/junk_edgewater.csv
# ✅ Saved 15 records for 'NORWOOD PARK' to ../data/junk_review/junk_norwood_park.csv
# ✅ Saved 7 records for 'BEVERLY' to ../data/junk_review/junk_beverly.csv
# ✅ Saved 5 records for 'FOREST GLEN' to ../data/junk_review/junk_forest_glen.csv
# ✅ Saved 9 records for 'FULLER PARK' to ../data/junk_review/junk_fuller_park.csv
# ✅ Saved 9 records for 'SOUTH DEERING' to ../data/junk_review/junk_south_deering.csv
# ✅ Saved 4 records for 'CLEARING' to ../data/junk_review/junk_clearing.csv
# ✅ Saved 1 records for 'NEAR SOUTH SIDE' to ../data/junk_review/junk_near_south_side.csv
# ✅ Saved 8 records for 'ARCHER HEIGHTS' to ../data/junk_review/junk_archer_heights.csv
# ✅ Saved 14 records for 'BRIGHTON PARK' to ../data/junk_review/junk_brighton_park.csv
# ✅ Saved 6 records for 'HYDE PARK' to ../data/junk_review/junk_hyde_park.csv
# ✅ Saved 7 records for 'BRIDGEPORT' to ../data/junk_review/junk_bridgeport.csv
# ✅ Saved 3 records for 'DOUGLAS' to ../data/junk_review/junk_douglas.csv
# ✅ Saved 4 records for 'HEGEWISCH' to ../data/junk_review/junk_hegewisch.csv
# ✅ Saved 2 records for 'RIVERDALE' to ../data/junk_review/junk_riverdale.csv
# ✅ Saved 2 records for 'EDISON PARK' to ../data/junk_review/junk_edison_park.csv
